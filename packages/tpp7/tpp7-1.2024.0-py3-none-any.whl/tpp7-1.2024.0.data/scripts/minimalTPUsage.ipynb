# %%
import matplotlib.pyplot as plt
from Oscillo import Oscillo
import warnings

devList = Oscillo.getDeviceList()
print(devList)
# Out:
# [<DEVICE ID 0699:03aa on Bus 001 Address 125>]

# %%
osc = Oscillo.openDevice(devList[0])
print(osc)
idn = osc.instr.ask("*IDN?")
print(idn)
print(osc.instr.max_transfer_size)
# Out:
# TEKTRONIX TDS 1001C-EDU
# vendor : TEKTRONIX, model: TDS 1001C-EDU
# serie : TDS, model: 1001C-EDU
# <Oscillo.Tektronix_TDS.TDS object at 0x7f75f9556de0>
# TEKTRONIX,TDS 1001C-EDU,C011782,CF:91.1CT FV:v25.04
# 1048576

# %%
hc = osc.getHardcopy()
plt.imsave('hardcopy.png', hc)
plt.figure()
plt.imshow(hc)
plt.show()

# %%
activeChannelList = osc.getActiveChannelList()
print(activeChannelList)
data = osc.getChannelListData(activeChannelList)
plt.figure()
osc.plotData(data)
plt.show()
# Out:
# ['CH1', 'CH2']

# %%
osc.instr.clear()
osc.instr.device.reset()
osc.instr.close()
