# %%
import logging
from pathlib import Path
import subprocess

from pytube import YouTube

from lioness.nodes.project_logging import default_logging

default_logging()

logging.getLogger('pytube').setLevel(logging.INFO)
logger = logging.getLogger(__name__)

BASE_DIRECTORY = Path('../data')
VIDEO_DIRECTORY = BASE_DIRECTORY / 'videos'
AUDIO_DIRECTORY = BASE_DIRECTORY / 'audios'
COMBINED_DIRECTORY = BASE_DIRECTORY / 'combined'

# Create directories if they do not exist
VIDEO_DIRECTORY.mkdir(parents=True, exist_ok=True)
AUDIO_DIRECTORY.mkdir(parents=True, exist_ok=True)
COMBINED_DIRECTORY.mkdir(parents=True, exist_ok=True)

video_url = 'https://youtu.be/zP1fojwJZIc?si=9mnpmFewtJvi4T0n'

def download_and_merge(video_url):
    video = YouTube(video_url)

    # Select the highest resolution video stream with progressive=False
    video_stream = video.streams.filter(progressive=False, file_extension='mp4', type='video').order_by('resolution').desc().first()
    # Select the highest quality audio stream
    audio_stream = video.streams.filter(progressive=False, file_extension='mp4', type='audio').order_by('abr').desc().first()

    # Download video and audio streams
    video_filename = video_stream.default_filename
    audio_filename = video_stream.default_filename.replace('.mp4', '.mp3')

    video_file = VIDEO_DIRECTORY / video_filename
    audio_file = AUDIO_DIRECTORY / audio_filename

    video_stream.download(output_path=VIDEO_DIRECTORY, filename=video_filename)
    audio_stream.download(output_path=AUDIO_DIRECTORY, filename=audio_filename)

    logger.info(f'Downloaded video: {video_file}')
    logger.info(f'Downloaded audio: {audio_file}')

    # Define the output file path
    output_file = COMBINED_DIRECTORY / video_filename

    # Merge video and audio using ffmpeg
    ffmpeg_command = [
        'ffmpeg', '-i', str(video_file), '-i', str(audio_file), '-c:v', 'copy', '-c:a', 'aac', '-strict', 'experimental', str(output_file)
    ]
    subprocess.run(ffmpeg_command)

    logger.info(f'Final video saved to: {output_file}')

# %%
download_and_merge(video_url=video_url)
# Out:
# 2024-06-17 15:31:39,733 pytube.helpers - DEBUG:matched regex search: (?:v=|\/)([0-9A-Za-z_-]{11}).*
# 2024-06-17 15:31:40,917 pytube.extract - DEBUG:applying descrambler
# 2024-06-17 15:31:40,918 pytube.extract - DEBUG:finding initial function name
# 2024-06-17 15:31:40,920 pytube.extract - DEBUG:Pattern failed: ytplayer\.config\s*=\s*
# 2024-06-17 15:31:40,920 pytube.extract - DEBUG:Could not parse object.
# 2024-06-17 15:31:40,945 pytube.extract - DEBUG:finished regex search, matched: (/s/player/[\w\d]+/[\w\d_/.]+/base\.js)
# 2024-06-17 15:31:42,347 pytube.cipher - DEBUG:finding initial function name
# 2024-06-17 15:31:42,542 pytube.cipher - DEBUG:finished regex search, matched: (?P<sig>[a-zA-Z0-9$]+)\s*=\s*function\(\s*a\s*\)\s*{\s*a\s*=\s*a\.split\(\s*""\s*\)
# 2024-06-17 15:31:42,542 pytube.cipher - DEBUG:getting transform plan
# 2024-06-17 15:31:42,543 pytube.helpers - DEBUG:matched regex search: zPa=function\(\w\){[a-z=\.\(\"\)]*;(.*);(?:.+)}
# 2024-06-17 15:31:42,544 pytube.cipher - DEBUG:getting transform object
# 2024-06-17 15:31:42,545 pytube.cipher - DEBUG:Finding throttling function name
# 2024-06-17 15:31:42,547 pytube.cipher - DEBUG:finished regex search, matched: a\.[a-zA-Z]\s*&&\s*\([a-z]\s*=\s*a\.get\("n"\)\)\s*&&\s*\([a-z]\s*=\s*([a-zA-Z0-9$]+)(\[\d+\])?\([a-z]\)
# 2024-06-17 15:31:42,551 pytube.cipher - DEBUG:Finding throttling function name
# 2024-06-17 15:31:42,552 pytube.cipher - DEBUG:finished regex search, matched: a\.[a-zA-Z]\s*&&\s*\([a-z]\s*=\s*a\.get\("n"\)\)\s*&&\s*\([a-z]\s*=\s*([a-zA-Z0-9$]+)(\[\d+\])?\([a-z]\)
# 2024-06-17 15:31:42,556 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,557 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,558 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,558 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,559 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,560 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,560 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,561 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,561 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,562 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,562 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,563 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,563 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,565 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,565 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,566 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,566 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,567 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,567 pytube.extract - DEBUG:signature found, skip decipher
# 2024-06-17 15:31:42,620 pytube.streams - DEBUG:downloading (1303368936 total bytes) file to /workspaces/lioness/notebooks/../data/videos/FULL FIGHT  Dmitry Bivol vs Joe Smith Jr.mp4
# 2024-06-17 15:31:49,074 pytube.streams - DEBUG:download remaining: 1293931752
# 2024-06-17 15:31:54,724 pytube.streams - DEBUG:download remaining: 1284494568
# 2024-06-17 15:32:01,629 pytube.streams - DEBUG:download remaining: 1275057384
# 2024-06-17 15:32:08,764 pytube.streams - DEBUG:download remaining: 1265620200
# 2024-06-17 15:32:19,251 pytube.streams - DEBUG:download remaining: 1256183016
# 2024-06-17 15:32:27,456 pytube.streams - DEBUG:download remaining: 1246745832
# 2024-06-17 15:32:31,954 pytube.streams - DEBUG:download remaining: 1237308648
# 2024-06-17 15:32:37,840 pytube.streams - DEBUG:download remaining: 1227871464
# 2024-06-17 15:32:44,747 pytube.streams - DEBUG:download remaining: 1218434280
# 2024-06-17 15:32:50,690 pytube.streams - DEBUG:download remaining: 1208997096
# 2024-06-17 15:32:56,103 pytube.streams - DEBUG:download remaining: 1199559912
# 2024-06-17 15:33:00,797 pytube.streams - DEBUG:download remaining: 1190122728
# 2024-06-17 15:33:05,504 pytube.streams - DEBUG:download remaining: 1180685544
# 2024-06-17 15:33:10,014 pytube.streams - DEBUG:download remaining: 1171248360
# 2024-06-17 15:33:15,576 pytube.streams - DEBUG:download remaining: 1161811176
# 2024-06-17 15:33:20,653 pytube.streams - DEBUG:download remaining: 1152373992
# 2024-06-17 15:33:26,972 pytube.streams - DEBUG:download remaining: 1142936808
# 2024-06-17 15:33:34,769 pytube.streams - DEBUG:download remaining: 1133499624
# 2024-06-17 15:33:41,452 pytube.streams - DEBUG:download remaining: 1124062440
# 2024-06-17 15:33:52,130 pytube.streams - DEBUG:download remaining: 1114625256
# 2024-06-17 15:33:59,924 pytube.streams - DEBUG:download remaining: 1105188072
# 2024-06-17 15:34:06,656 pytube.streams - DEBUG:download remaining: 1095750888
# 2024-06-17 15:34:13,278 pytube.streams - DEBUG:download remaining: 1086313704
# 2024-06-17 15:34:17,911 pytube.streams - DEBUG:download remaining: 1076876520
# 2024-06-17 15:34:22,202 pytube.streams - DEBUG:download remaining: 1067439336
# 2024-06-17 15:34:27,144 pytube.streams - DEBUG:download remaining: 1058002152
# 2024-06-17 15:34:31,954 pytube.streams - DEBUG:download remaining: 1048564968
# 2024-06-17 15:34:40,328 pytube.streams - DEBUG:download remaining: 1039127784
# 2024-06-17 15:34:46,479 pytube.streams - DEBUG:download remaining: 1029690600
# 2024-06-17 15:34:57,261 pytube.streams - DEBUG:download remaining: 1020253416
# 2024-06-17 15:35:04,421 pytube.streams - DEBUG:download remaining: 1010816232
# 2024-06-17 15:35:11,999 pytube.streams - DEBUG:download remaining: 1001379048
# 2024-06-17 15:35:17,868 pytube.streams - DEBUG:download remaining: 991941864
# 2024-06-17 15:35:26,108 pytube.streams - DEBUG:download remaining: 982504680
# 2024-06-17 15:35:35,331 pytube.streams - DEBUG:download remaining: 973067496
# 2024-06-17 15:35:43,600 pytube.streams - DEBUG:download remaining: 963630312
# 2024-06-17 15:35:49,539 pytube.streams - DEBUG:download remaining: 954193128
# 2024-06-17 15:35:54,047 pytube.streams - DEBUG:download remaining: 944755944
# 2024-06-17 15:35:59,964 pytube.streams - DEBUG:download remaining: 935318760
# 2024-06-17 15:36:04,103 pytube.streams - DEBUG:download remaining: 925881576
# 2024-06-17 15:36:08,422 pytube.streams - DEBUG:download remaining: 916444392
# 2024-06-17 15:36:14,154 pytube.streams - DEBUG:download remaining: 907007208
# 2024-06-17 15:36:19,669 pytube.streams - DEBUG:download remaining: 897570024
# 2024-06-17 15:36:25,063 pytube.streams - DEBUG:download remaining: 888132840
# 2024-06-17 15:36:30,027 pytube.streams - DEBUG:download remaining: 878695656
# 2024-06-17 15:36:38,483 pytube.streams - DEBUG:download remaining: 869258472
# 2024-06-17 15:36:44,422 pytube.streams - DEBUG:download remaining: 859821288
# 2024-06-17 15:36:49,047 pytube.streams - DEBUG:download remaining: 850384104
# 2024-06-17 15:36:53,395 pytube.streams - DEBUG:download remaining: 840946920
# 2024-06-17 15:36:57,889 pytube.streams - DEBUG:download remaining: 831509736
# 2024-06-17 15:37:02,234 pytube.streams - DEBUG:download remaining: 822072552
# 2024-06-17 15:37:09,229 pytube.streams - DEBUG:download remaining: 812635368
# 2024-06-17 15:37:14,965 pytube.streams - DEBUG:download remaining: 803198184
# 2024-06-17 15:37:21,607 pytube.streams - DEBUG:download remaining: 793761000
# 2024-06-17 15:37:27,026 pytube.streams - DEBUG:download remaining: 784323816
# 2024-06-17 15:37:32,138 pytube.streams - DEBUG:download remaining: 774886632
# 2024-06-17 15:37:37,347 pytube.streams - DEBUG:download remaining: 765449448
# 2024-06-17 15:37:42,107 pytube.streams - DEBUG:download remaining: 756012264
# 2024-06-17 15:37:46,333 pytube.streams - DEBUG:download remaining: 746575080
# 2024-06-17 15:37:50,968 pytube.streams - DEBUG:download remaining: 737137896
# 2024-06-17 15:37:55,320 pytube.streams - DEBUG:download remaining: 727700712
# 2024-06-17 15:37:59,519 pytube.streams - DEBUG:download remaining: 718263528
# 2024-06-17 15:38:05,413 pytube.streams - DEBUG:download remaining: 708826344
# 2024-06-17 15:38:11,396 pytube.streams - DEBUG:download remaining: 699389160
# 2024-06-17 15:38:17,482 pytube.streams - DEBUG:download remaining: 689951976
# 2024-06-17 15:38:23,267 pytube.streams - DEBUG:download remaining: 680514792
# 2024-06-17 15:38:28,687 pytube.streams - DEBUG:download remaining: 671077608
# 2024-06-17 15:38:33,375 pytube.streams - DEBUG:download remaining: 661640424
# 2024-06-17 15:38:37,886 pytube.streams - DEBUG:download remaining: 652203240
# 2024-06-17 15:38:42,921 pytube.streams - DEBUG:download remaining: 642766056
# 2024-06-17 15:38:47,170 pytube.streams - DEBUG:download remaining: 633328872
# 2024-06-17 15:38:53,353 pytube.streams - DEBUG:download remaining: 623891688
# 2024-06-17 15:38:58,952 pytube.streams - DEBUG:download remaining: 614454504
# 2024-06-17 15:39:04,721 pytube.streams - DEBUG:download remaining: 605017320
# 2024-06-17 15:39:10,792 pytube.streams - DEBUG:download remaining: 595580136
# 2024-06-17 15:39:19,433 pytube.streams - DEBUG:download remaining: 586142952
# 2024-06-17 15:39:25,790 pytube.streams - DEBUG:download remaining: 576705768
# 2024-06-17 15:39:32,182 pytube.streams - DEBUG:download remaining: 567268584
# 2024-06-17 15:39:43,811 pytube.streams - DEBUG:download remaining: 557831400
# 2024-06-17 15:40:11,135 pytube.streams - DEBUG:download remaining: 548394216
# 2024-06-17 15:40:24,043 pytube.streams - DEBUG:download remaining: 538957032
# 2024-06-17 15:40:31,087 pytube.streams - DEBUG:download remaining: 529519848
# 2024-06-17 15:40:48,863 pytube.streams - DEBUG:download remaining: 520082664
# 2024-06-17 15:40:59,616 pytube.streams - DEBUG:download remaining: 510645480
# 2024-06-17 15:41:08,744 pytube.streams - DEBUG:download remaining: 501208296
# 2024-06-17 15:41:17,524 pytube.streams - DEBUG:download remaining: 491771112
# 2024-06-17 15:41:26,465 pytube.streams - DEBUG:download remaining: 482333928
# 2024-06-17 15:41:31,708 pytube.streams - DEBUG:download remaining: 472896744
# 2024-06-17 15:41:38,782 pytube.streams - DEBUG:download remaining: 463459560
# 2024-06-17 15:41:51,353 pytube.streams - DEBUG:download remaining: 454022376
# 2024-06-17 15:42:00,314 pytube.streams - DEBUG:download remaining: 444585192
# 2024-06-17 15:42:10,155 pytube.streams - DEBUG:download remaining: 435148008
# 2024-06-17 15:42:15,327 pytube.streams - DEBUG:download remaining: 425710824
# 2024-06-17 15:42:25,712 pytube.streams - DEBUG:download remaining: 416273640
# 2024-06-17 15:42:33,525 pytube.streams - DEBUG:download remaining: 406836456
# 2024-06-17 15:42:37,697 pytube.streams - DEBUG:download remaining: 397399272
# 2024-06-17 15:42:42,462 pytube.streams - DEBUG:download remaining: 387962088
# 2024-06-17 15:42:46,824 pytube.streams - DEBUG:download remaining: 378524904
# 2024-06-17 15:42:52,235 pytube.streams - DEBUG:download remaining: 369087720
# 2024-06-17 15:42:56,802 pytube.streams - DEBUG:download remaining: 359650536
# 2024-06-17 15:43:03,451 pytube.streams - DEBUG:download remaining: 350213352
# 2024-06-17 15:43:09,711 pytube.streams - DEBUG:download remaining: 340776168
# 2024-06-17 15:43:15,978 pytube.streams - DEBUG:download remaining: 331338984
# 2024-06-17 15:43:23,385 pytube.streams - DEBUG:download remaining: 321901800
# 2024-06-17 15:43:32,208 pytube.streams - DEBUG:download remaining: 312464616
# 2024-06-17 15:43:38,561 pytube.streams - DEBUG:download remaining: 303027432
# 2024-06-17 15:43:47,781 pytube.streams - DEBUG:download remaining: 293590248
# 2024-06-17 15:43:55,822 pytube.streams - DEBUG:download remaining: 284153064
# 2024-06-17 15:44:04,950 pytube.streams - DEBUG:download remaining: 274715880
# 2024-06-17 15:44:09,579 pytube.streams - DEBUG:download remaining: 265278696
# 2024-06-17 15:44:14,221 pytube.streams - DEBUG:download remaining: 255841512
# 2024-06-17 15:44:21,169 pytube.streams - DEBUG:download remaining: 246404328
# 2024-06-17 15:44:25,984 pytube.streams - DEBUG:download remaining: 236967144
# 2024-06-17 15:44:30,800 pytube.streams - DEBUG:download remaining: 227529960
# 2024-06-17 15:44:35,611 pytube.streams - DEBUG:download remaining: 218092776
# 2024-06-17 15:44:40,070 pytube.streams - DEBUG:download remaining: 208655592
# 2024-06-17 15:44:46,074 pytube.streams - DEBUG:download remaining: 199218408
# 2024-06-17 15:44:50,911 pytube.streams - DEBUG:download remaining: 189781224
# 2024-06-17 15:44:55,385 pytube.streams - DEBUG:download remaining: 180344040
# 2024-06-17 15:44:59,680 pytube.streams - DEBUG:download remaining: 170906856
# 2024-06-17 15:45:09,032 pytube.streams - DEBUG:download remaining: 161469672
# 2024-06-17 15:45:15,086 pytube.streams - DEBUG:download remaining: 152032488
# 2024-06-17 15:45:20,065 pytube.streams - DEBUG:download remaining: 142595304
# 2024-06-17 15:45:27,628 pytube.streams - DEBUG:download remaining: 133158120
# 2024-06-17 15:45:33,879 pytube.streams - DEBUG:download remaining: 123720936
# 2024-06-17 15:45:38,602 pytube.streams - DEBUG:download remaining: 114283752
# 2024-06-17 15:45:43,302 pytube.streams - DEBUG:download remaining: 104846568
# 2024-06-17 15:45:47,722 pytube.streams - DEBUG:download remaining: 95409384
# 2024-06-17 15:45:51,957 pytube.streams - DEBUG:download remaining: 85972200
# 2024-06-17 15:45:57,111 pytube.streams - DEBUG:download remaining: 76535016
# 2024-06-17 15:46:01,381 pytube.streams - DEBUG:download remaining: 67097832
# 2024-06-17 15:46:06,315 pytube.streams - DEBUG:download remaining: 57660648
# 2024-06-17 15:46:10,620 pytube.streams - DEBUG:download remaining: 48223464
# 2024-06-17 15:46:14,774 pytube.streams - DEBUG:download remaining: 38786280
# 2024-06-17 15:46:21,786 pytube.streams - DEBUG:download remaining: 29349096
# 2024-06-17 15:46:26,128 pytube.streams - DEBUG:download remaining: 19911912
# 2024-06-17 15:46:30,274 pytube.streams - DEBUG:download remaining: 10474728
# 2024-06-17 15:46:34,482 pytube.streams - DEBUG:download remaining: 1037544
# 2024-06-17 15:46:35,044 pytube.streams - DEBUG:download remaining: 0
# 2024-06-17 15:46:35,049 pytube.streams - DEBUG:download finished
# 2024-06-17 15:46:35,051 pytube.streams - DEBUG:downloading (50631414 total bytes) file to /workspaces/lioness/notebooks/../data/audios/FULL FIGHT  Dmitry Bivol vs Joe Smith Jr.mp3
# 2024-06-17 15:46:39,857 pytube.streams - DEBUG:download remaining: 41194230
# 2024-06-17 15:46:44,128 pytube.streams - DEBUG:download remaining: 31757046
# 2024-06-17 15:46:49,301 pytube.streams - DEBUG:download remaining: 22319862
# 2024-06-17 15:46:53,636 pytube.streams - DEBUG:download remaining: 12882678
# 2024-06-17 15:46:57,947 pytube.streams - DEBUG:download remaining: 3445494
# 2024-06-17 15:47:00,242 pytube.streams - DEBUG:download remaining: 0
# 2024-06-17 15:47:00,244 pytube.streams - DEBUG:download finished
# 2024-06-17 15:47:00,246 __main__ - INFO:Downloaded video: ../data/videos/FULL FIGHT  Dmitry Bivol vs Joe Smith Jr.mp4
# 2024-06-17 15:47:00,246 __main__ - INFO:Downloaded audio: ../data/audios/FULL FIGHT  Dmitry Bivol vs Joe Smith Jr.mp3
# ffmpeg version 5.1.5-0+deb12u1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12 (Debian 12.2.0-14)
#   configuration: --prefix=/usr --extra-version=0+deb12u1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librist --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --disable-sndio --enable-libjxl --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-libplacebo --enable-librav1e --enable-shared
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/FULL FIGHT  Dmitry Bivol vs Joe Smith Jr.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2024-03-17T05:00:10.000000Z
#   Duration: 00:52:08.40, start: 0.000000, bitrate: 3332 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 5 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       creation_time   : 2024-03-17T05:00:10.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/FULL FIGHT  Dmitry Bivol vs Joe Smith Jr.mp3':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2024-03-16T05:37:38.000000Z
#   Duration: 00:52:08.45, start: 0.000000, bitrate: 129 kb/s
#   Stream #1:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2024-03-16T05:37:38.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to '../data/combined/FULL FIGHT  Dmitry Bivol vs Joe Smith Jr.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf59.27.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 5 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       creation_time   : 2024-03-17T05:00:10.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2024-03-16T05:37:38.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 aac
# frame=77546 fps=1371 q=-1.0 size= 1318656kB time=00:51:41.76 bitrate=3482.7kbits/s speed=54.8x
# 2024-06-17 15:47:57,969 __main__ - INFO:Final video saved to: ../data/combined/FULL FIGHT  Dmitry Bivol vs Joe Smith Jr.mp4
# frame=78210 fps=1369 q=-1.0 Lsize= 1324007kB time=00:52:08.44 bitrate=3467.0kbits/s speed=54.8x
# video:1271841kB audio:49649kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.190410%
# [aac @ 0x56468fa96440] Qavg: 719.872
